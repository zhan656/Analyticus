# %%
# Dependencies
import json
import datetime
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.cbook as cbook
import numpy as np

# %%
# Read JSON file
with open('data/plot_national_10_years.json') as plot_national_10_file:
    plot_national_10_dict = json.load(plot_national_10_file)

# Converting JSON data file into DataFrame "df"
df_plot_national_10 = pd.DataFrame(plot_national_10_dict)

# Sort data by week number, start from week 1
df_plot_national_10 = df_plot_national_10.sort_values(by=['year','week'])

# Decimal adjustment
df_10 = df_plot_national_10.round({'flu_cases':0, 'flu_percent':2, "vac_percent":2, "vaccinations":0, "week":0})
df_10
# Out:
#      flu_cases  flu_percent  vac_pct_week  vac_percent  vaccinations  week  \
# 0         5687         0.88      0.000000         0.00           0.0     1
# 1         5959         0.92      0.000000         0.00           0.0     2
# 2         5896         0.91      0.000000         0.00           0.0     3
# 3         6485         1.00      0.000000         0.00           0.0     4
# 4         6987         1.08      0.000000         0.00           0.0     5
# 5         7297         1.13      0.000000         0.00           0.0     6
# 6         7667         1.19      0.000000         0.00           0.0     7
# 7         7733         1.20      0.000000         0.00           0.0     8
# 8         7634         1.18      0.000000         0.00           0.0     9
# 9         8708         1.35      0.000000         0.00           0.0    10
# 10        8689         1.34      0.000000         0.00           0.0    11
# 11        7812         1.21      0.000000         0.00           0.0    12
# 12        8706         1.35      0.000000         0.00           0.0    13
# 13        8603         1.33      0.000000         0.00           0.0    14
# 14        8956         1.39      0.000000         0.00           0.0    14
# 15        9289         1.44      0.000000         0.00           0.0    15
# 16       11456         1.77      0.000000         0.00           0.0    16
# 17       14324         2.22      0.000000         0.00           0.0    17
# 18       18268         2.83      0.000000         0.00           0.0    18
# 19       21667         3.35      0.000000         0.00           0.0    19
# 20       20022         3.10      0.000000         0.00           0.0    20
# 21       20450         3.17      0.000000         0.00           0.0    21
# 22       18441         2.85      0.000000         0.00           0.0    22
# 23       15711         2.43      0.000000         0.00           0.0    23
# 24       13277         2.05      0.000000         0.00           0.0    24
# 25       11400         1.76      0.000000         0.00           0.0    25
# 26        9669         1.50      0.000000         0.00           0.0    26
# 27        8460         1.31      0.000000         0.00           0.0    27
# 28        7222         1.12      0.000000         0.00           0.0    28
# 29        7348         1.14      0.000000         0.00           0.0    29
# ..         ...          ...           ...          ...           ...   ...
# 465       7133         0.87      0.000200        48.69    29624654.0    48
# 466       7073         0.86      0.000200        48.69    29624654.0    49
# 467       8317         1.01      0.000200        48.69    29624654.0    50
# 468       8566         1.04      0.000000        48.69    29624654.0    51
# 469       9079         1.10      0.000000        48.69    29624654.0    52
# 470      13021         1.36      0.169688         0.17    31422333.0     1
# 471      13292         1.39      0.337779         0.51    31422333.0     2
# 472      14357         1.50      0.540393         1.05    31422333.0     3
# 473      15845         1.66      0.960920         2.01    31422333.0     4
# 474      17081         1.79      1.629500         3.64    31422333.0     5
# 475      18973         1.99      2.825200         6.46    31422333.0     6
# 476      21785         2.28      3.673520        10.14    31422333.0     7
# 477      19716         2.07      4.520600        14.66    31422333.0     8
# 478      23756         2.49      5.676400        20.33    31422333.0     9
# 479      24812         2.60      5.268000        25.60    31422333.0    10
# 480      31454         3.30      4.784500        30.39    31422333.0    11
# 481      42536         4.46      3.883400        34.27    31422333.0    12
# 482      44965         4.71      2.946000        37.22    31422333.0    13
# 483      47199         4.95      2.365400        39.58    31422333.0    14
# 484      56639         5.94      1.880700        41.46    31422333.0    15
# 485      62929         6.60      0.867500        42.33    31422333.0    16
# 486      77019         8.07      1.121300        43.45    31422333.0    17
# 487      85128         8.92      0.933700        44.38    31422333.0    18
# 488      87008         9.12      0.736400        45.12    31422333.0    19
# 489      75349         7.90      0.488300        45.61    31422333.0    20
# 490      52348         5.49      0.209500        45.82    31422333.0    21
# 491      35079         3.68      0.100900        45.92    31422333.0    22
# 492      28221         2.96      0.065100        45.98    31422333.0    23
# 493      24251         2.54      0.002600        45.99    31422333.0    24
# 494      21379         2.24      0.000000        45.99    31422333.0    25
#
#      year
# 0    2008
# 1    2008
# 2    2008
# 3    2008
# 4    2008
# 5    2008
# 6    2008
# 7    2008
# 8    2008
# 9    2008
# 10   2008
# 11   2008
# 12   2008
# 13   2008
# 14   2008
# 15   2008
# 16   2008
# 17   2008
# 18   2008
# 19   2008
# 20   2008
# 21   2008
# 22   2008
# 23   2008
# 24   2008
# 25   2008
# 26   2008
# 27   2008
# 28   2008
# 29   2008
# ..    ...
# 465  2016
# 466  2016
# 467  2016
# 468  2016
# 469  2016
# 470  2017
# 471  2017
# 472  2017
# 473  2017
# 474  2017
# 475  2017
# 476  2017
# 477  2017
# 478  2017
# 479  2017
# 480  2017
# 481  2017
# 482  2017
# 483  2017
# 484  2017
# 485  2017
# 486  2017
# 487  2017
# 488  2017
# 489  2017
# 490  2017
# 491  2017
# 492  2017
# 493  2017
# 494  2017
#
# [495 rows x 7 columns]

# %%
df_trend = df_10.groupby(['year'])
print(df_trend)
df_year_trendline = df_trend.sum()
df_year_trendline
# Out:
# <pandas.core.groupby.DataFrameGroupBy object at 0x1a15374da0>
#       flu_cases  flu_percent  vac_pct_week  vac_percent  vaccinations  week
# year
# 2008     646101        99.99        0.0000         0.00  0.000000e+00  1392
# 2009     824107       100.02        0.0000         0.00  0.000000e+00  1378
# 2010     644978        99.99        0.0000         0.00  0.000000e+00  1378
# 2011     515225       100.00        0.0000         0.00  0.000000e+00  1378
# 2012     728957        99.97        0.0056       512.40  2.604383e+08  1378
# 2013     668021        99.98       50.5152      2150.57  1.418501e+09  1378
# 2014     780583        99.98       52.2221      2193.47  1.528007e+09  1392
# 2015     667748       100.00       48.5707      2045.26  1.534896e+09  1378
# 2016     822732       100.02       48.6903      2035.67  1.540482e+09  1378
# 2017     954142       100.01       45.9873       718.08  7.855583e+08   325

# %%
# Create the data
x_axis = ('2008','2009','2010','2011','2012','2013','2014','2015','2016','2017')
y_axis = df_year_trendline["flu_cases"]

# %%
fig, ax = plt.subplots(figsize=(32, 24), dpi=100, facecolor='w', edgecolor='k')
ax.plot(x_axis, y_axis, color="Cornflowerblue", label="Flu Cases", linewidth = 7.0)
ax.set_title('Number of Flu Cases, Year 2008 - 2017', fontsize = 40)
ax.set_xlabel('Year', fontsize = 50)
ax.set_ylabel('Flu Cases', fontsize = 50)
ax.spines['bottom'].set_linewidth(5)

ax.legend(loc=2, prop={'size': 40})

# Tick labels fontsize
plt.tick_params(labelsize=30)

ax.grid(True)
fig.autofmt_xdate()

# Export to PNG file
plt.savefig('Number of Flu Cases_2008-2017.png')
