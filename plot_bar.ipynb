# %% [markdown]
# # Plot Bar

# %%
# Dependencies
import json
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Read JSON file
file_path = ("plot.json")
plot_data = pd.read_json(file_path,typ='frame')

# Transponse index and columns
plot_df = plot_data.transpose()
plot_df
# Out:
#       cases                 state tweets week  year
# 0       698               Alabama      0   40  2017
# 1       326                Alaska      0   40  2017
# 10      850               Georgia      0   40  2017
# 100    1141              Virginia      0   41  2017
# 1000    536                Nevada      0    6  2018
# 1001    225         New Hampshire      0    6  2018
# 1002   3301            New Jersey      0    6  2018
# 1003   1995            New Mexico      0    6  2018
# 1004   1678              New York      0    6  2018
# 1005   1973        North Carolina      0    6  2018
# 1006     65          North Dakota      0    6  2018
# 1007   1098                  Ohio      0    6  2018
# 1008    760              Oklahoma      0    6  2018
# 1009   1406                Oregon      0    6  2018
# 101      28            Washington      0   41  2017
# 1010   4171          Pennsylvania      0    6  2018
# 1011    507          Rhode Island      0    6  2018
# ...

# %% [markdown]
# ##### bar by state

# %%
# Set x, y axis
x_axis = np.arange(len(plot_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, plot_df["cases"], color="r", alpha=0.5, align="edge")
plt.xticks(tick_locations, plot_df["state"], rotation="vertical")
# Set a Title and labels
plt.title("States with influence")
plt.xlabel("State")
plt.ylabel("Twitter vs HHS")
# Out:
# Text(0,0.5,'Twitter vs HHS')

# %%
# Save graph
plt.savefig("bar_by_state.png")
plt.show()

# %% [markdown]
# ##### bar by week

# %% [markdown]
# ##### regression

# %% [markdown]
# ##### Export the data in the DataFrame into a CSV file
