# %% [markdown]
# <p>Class:  USC Viterbi Data Analytics Bootcamp</p>
# <p>Team:  Analyticus (aka Team 5)</p>
# <p>Module:  pull_hhs_state_5_years.py</p>
# <p>Version:  March 31, 2018</p>
# <p>Input:  HHS Vaccinations by state from HHS API for six flu seasons.</p>
# <p>Output:  HHS Vaccinations Json File by state for six flu season.</p>

# %%
# Dependencies
import requests
import json
import numpy as np
import pandas as pd

# %%
# Prepare the url for retreiving the state codes used in pulling HHS data via API.
url = "https://fluvaccineapi.hhs.gov/api/v2/ids/2017/states.json"

# %%
# Create a list of state codes.  Remove District of Columbia and Puerto Rico.
state_codes = requests.get(url).json()
state_codes.remove('DC')
state_codes.remove('PR')

# %%
# Build a datafram of HHS data by appending data for each state within each year.
df1 = pd.DataFrame()

year_list = [2012, 2013, 2014, 2015, 2016, 2017]

for year_entry in year_list:
    
    for state_code in state_codes:
        
        url = "https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/{}/states/{}.json?ethnicity=T&medicare_status=A".format(year_entry, state_code)
        
        state_dict = requests.get(url).json()
    
        df = pd.DataFrame(state_dict)
    
        df1 = df1.append(df, ignore_index=True)
# Out:
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/AK.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/AL.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/AR.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/AZ.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/CA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/CO.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/CT.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/DE.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/FL.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/GA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/HI.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/IA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/ID.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/IL.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/IN.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/KS.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/KY.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/LA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/MA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/MD.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/ME.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/MI.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/MN.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/MO.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/MS.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/MT.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/NC.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/ND.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/NE.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/NH.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/NJ.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/NM.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/NV.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/NY.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/OH.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/OK.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/OR.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/PA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/RI.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/SC.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/SD.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/TN.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/TX.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/UT.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/VA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/VT.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/WA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/WI.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/WV.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2012/states/WY.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/AK.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/AL.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/AR.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/AZ.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/CA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/CO.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/CT.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/DE.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/FL.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/GA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/HI.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/IA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/ID.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/IL.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/IN.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/KS.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/KY.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/LA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/MA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/MD.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/ME.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/MI.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/MN.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/MO.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/MS.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/MT.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/NC.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/ND.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/NE.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/NH.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/NJ.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/NM.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/NV.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/NY.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/OH.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/OK.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/OR.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/PA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/RI.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/SC.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/SD.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2013/states/TN.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/
json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2016/states/WI.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2016/states/WV.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2016/states/WY.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/AK.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/AL.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/AR.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/AZ.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/CA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/CO.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/CT.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/DE.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/FL.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/GA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/HI.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/IA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/ID.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/IL.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/IN.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/KS.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/KY.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/LA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/MA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/MD.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/ME.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/MI.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/MN.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/MO.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/MS.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/MT.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/NC.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/ND.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/NE.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/NH.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/NJ.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/NM.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/NV.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/NY.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/OH.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/OK.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/OR.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/PA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/RI.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/SC.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/SD.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/TN.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/TX.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/UT.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/VA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/VT.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/WA.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/WI.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/WV.json?ethnicity=T&medicare_status=A
# https://fluvaccineapi.hhs.gov/api/v2/vaccination_rates/trends/2017/states/WY.json?ethnicity=T&medicare_status=A

# %%
# Inspect the HHS data that was downloaded.
df1.head()
# Out:
#    count  disparity ethnicity fips medicare_status    name  percentage  \
# 0  49908        0.0         T    2               A  Alaska    0.000882
# 1  49908        0.0         T    2               A  Alaska    0.003466
# 2  49908        0.0         T    2               A  Alaska    0.008656
# 3  49908        0.0         T    2               A  Alaska    0.021960
# 4  49908        0.0         T    2               A  Alaska    0.045744
#
#   short_name  week week_start  year
# 0         AK     1      11AUG  2012
# 1         AK     2      18AUG  2012
# 2         AK     3      25AUG  2012
# 3         AK     4      01SEP  2012
# 4         AK     5      08SEP  2012

# %%
# Write the downloaded data to a json file.
# This serves as a checkpoint in processing.
df1.to_json('../data/raw_hhs_state_data.json')

# %%
# Load a dataframe with the downloaded data.
# This serves as a restart point in processing.
df2 = pd.read_json('../data/raw_hhs_state_data.json')

# %%
# Inspect the downloaded HHS data.
df2.head()
# Out:
#        count  disparity ethnicity  fips medicare_status      name  percentage  \
# 0      49908          0         T     2               A    Alaska    0.000882
# 1      49908          0         T     2               A    Alaska    0.003466
# 10     49908          0         T     2               A    Alaska    0.247916
# 100   544894          0         T     1               A   Alabama    0.478945
# 1000  554052          0         T    24               A  Maryland    0.435544
#
#      short_name  week week_start  year
# 0            AK     1      11AUG  2012
# 1            AK     2      18AUG  2012
# 10           AK    11      20OCT  2012
# 100          AL    49      13JUL  2012
# 1000         MD    13      03NOV  2012

# %%
# Select only affected attributes.
df3 = df2[['count', 'percentage', 'year', 'week', 'name']]

# %%
# Rename the selected attributes to match the CCD data.
df4 = df3.rename(columns={"count":"vaccinations", "percentage":"vac_percent", "name":"state"})

# %%
# Sort the HHS data by year, state, and week to aid in inspection.
df5 = df4.sort_values(by=['year', 'state', 'week'])

# %%
# Inspect the sorted data.
df5.head()
# Out:
#     vaccinations  vac_percent  year  week    state
# 52        544894     0.001164  2012     1  Alabama
# 53        544894     0.004680  2012     2  Alabama
# 54        544894     0.011485  2012     3  Alabama
# 55        544894     0.026205  2012     4  Alabama
# 56        544894     0.049857  2012     5  Alabama

# %%
# Add attribute "vaccination percentage by week".
df5['vac_pct_week'] = 0.0

# %%
# Convert the vaccination ratio to a percentage.
df5['vac_percent'] = df5['vac_percent'] * 100

# %%
# Inspect the HHS dataframe for the changes.
df5.head()
# Out:
#     vaccinations  vac_percent  year  week    state  vac_pct_week
# 52        544894     0.116353  2012     1  Alabama           0.0
# 53        544894     0.467981  2012     2  Alabama           0.0
# 54        544894     1.148480  2012     3  Alabama           0.0
# 55        544894     2.620510  2012     4  Alabama           0.0
# 56        544894     4.985740  2012     5  Alabama           0.0

# %%
# Calculate the percentage for each week by finding the difference in the culumulative percentage for consecutive weeks.
for index_entry in df5.index:
    if df5.loc[index_entry, 'week'] == 1:
        df5.loc[index_entry, 'vac_pct_week'] = df5.loc[index_entry, 'vac_percent']
    elif index_entry > 0:
        i = index_entry - 1
        df5.loc[index_entry, 'vac_pct_week'] = df5.loc[index_entry, 'vac_percent'] - df5.loc[i, 'vac_percent']

# %%
# Inspect the HHS dataframe for the calculation.
df5.head()
# Out:
#     vaccinations  vac_percent  year  week    state  vac_pct_week
# 52        544894     0.116353  2012     1  Alabama      0.116353
# 53        544894     0.467981  2012     2  Alabama      0.351628
# 54        544894     1.148480  2012     3  Alabama      0.680499
# 55        544894     2.620510  2012     4  Alabama      1.472030
# 56        544894     4.985740  2012     5  Alabama      2.365230

# %%
# Write the HHS data for states for five years to a json file.
df5.to_json('../data/hhs_state_5_years.json')

# %%
# Validate the json file by loading it into a dataframe.
df6 = pd.read_json('../data/hhs_state_5_years.json')

# %%
# Sort the HHS data by year, state, and week to aid in inspection.
df7 = df6.sort_values(['year', 'state', 'week'])

# %%
# Inspect the HHS data.
df7.head()
# Out:
#       state  vac_pct_week  vac_percent  vaccinations  week  year
# 52  Alabama      0.116353     0.116353        544894     1  2012
# 53  Alabama      0.351628     0.467981        544894     2  2012
# 54  Alabama      0.680499     1.148480        544894     3  2012
# 55  Alabama      1.472030     2.620510        544894     4  2012
# 56  Alabama      2.365230     4.985740        544894     5  2012

# %%
# Inspect the HHS data.
df7.tail()
# Out:
#          state  vac_pct_week  vac_percent  vaccinations  week  year
# 14245  Wyoming        0.1988      41.7032         86509    21  2017
# 14246  Wyoming        0.1202      41.8234         86509    22  2017
# 14247  Wyoming        0.1318      41.9552         86509    23  2017
# 14248  Wyoming        0.0011      41.9563         86509    24  2017
# 14249  Wyoming        0.0000      41.9563         86509    25  2017
